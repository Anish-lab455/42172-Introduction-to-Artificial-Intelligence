# %% [markdown]
# # Task 1

# %% [markdown]
# #### Step 1 -- Generate solutions

# %% [markdown]
# Extract Task 1 - Part 1 specification and add it here for your reference:

# %% [markdown]
# Add your prompts for generating Part 1 solution here (starting and ending prompts attemped):

# %%
# Add your investigated solution of Task 1- Part 1 here
def add(a, b):
    return a + b

# %%
#@title #### Step 2 -- Part 1 Test: Run this cell to test your solution.
"""Test"""
import random
a = random.randint(0, 100)
b = random.randint(0, 100)
if add(a, b) == a + b:
    print ('Code Correct')
else:
    print ('Code Incorrect, Expected result: {}'.format(a + b))
# Out:
# Code Correct

# %% [markdown]
# #### Step 3 -- Write your own Part 1 test and test your solution (Optional).

# %% [markdown]
# Add your prompts used for generating this test code here:

# %%
# Add your test code here and compare with the provided one
def add(a, b):
    return a + b

def input_add(a, b):
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))
    addition = add(a, b)

    return a, b, addition

result_a, result_b, result = input_add(0, 0)
if result == result_a + result_b:
    print('Code Correct')
else:
    print('Code Incorrect, Expected result: {}'.format(result_a + result_b))
# Out:
# Code Correct

# %% [markdown]
# #### Step 4 -- Generate solutions of Part 2

# %% [markdown]
# Extract Task 1 - Part 2 specification and add it here for your reference:

# %% [markdown]
# Add your prompts for generating Part 2 solution here (starting and ending prompts attemped):

# %%
# Add your investigated solution of Task 1- Part 2 here

# %%
#@title #### Step 5 -- Part 2 Test: Run this cell to test your solution.
"""Test"""
result, a, b = input_add()
if result == add(int(a),int(b)):
    print ("Code Correct")
else:
    print ('Code Incorrect, Expected result: {}'.format(add(int(a),int(b))))
# Out:
# Enter the first integer: 12
# Enter the second integer: 30
# Code Correct

# %% [markdown]
# #### Step 6 -- Write your own Part 2 test and test your solution (Optional).

# %% [markdown]
# Add your prompts used for generating this test code here:

# %%
# Add your test code here and compare with the provided one

# %% [markdown]
# #### Step 7 -- Design and run a scenario of calling this function input_add()

# %% [markdown]
# Add your prompts used for generating this function call here.

# %% [markdown]
# # Task 2

# %% [markdown]
# #### Step 1: Generate solution

# %% [markdown]
# Extract Task 2 specification and add it here for your reference:

# %% [markdown]
# Add your prompts for generating Task 2 solution here (starting and ending prompts attemped):

# %%
# Add your investigated solution of Task 2 here
def loop_test():
    for i in range(5):
        print("Iteration:", i)

# %%
#@title #### Step 2 -- Task 2 Test: Run this cell to test your solution.
"""Test"""
num = int (input ("Enter the size of this list: "))
solution_list = list(range(1, num + 1))
try:
    code_passed = True
    if loop_test(num)[0] == solution_list and loop_test(num)[1] == solution_list:
        pass
    else:
        code_passed = False
        print ('Code Incorrect, Expected result: {}'.format((solution_list, solution_list)))

    if code_passed:
        print ("Code Correct")
except:
    print ('loop_test() method returns wrong value')
# Out:
# Enter the size of this list: 10
# Code Correct

# %% [markdown]
# #### Step 3 -- Write and run your own test (Optional)

# %% [markdown]
# Add your prompts used for generating this test code here:

# %%
# Add your test code here and compare with the provided one

# %% [markdown]
# #### Step 4 -- Design a scenario to use this function loop_test()

# %% [markdown]
# Add your prompts used for generating this function call here.

# %%
# Add your investigated code here

# %% [markdown]
# # Task 3

# %% [markdown]
# #### Step 1: Generate solution

# %% [markdown]
# Extract Task 3 specification and add it here for your reference:

# %% [markdown]
# Add your prompts for generating Task 3 solution here (starting and ending prompts attemped):

# %%
# Add your investigated solution of Task 3 here

# %%
#@title #### Step 2 -- Task 3 Test: Run this cell to test your solution.
"""Test"""
num = int (input ("Enter the size of this list: "))
if (num < 1) or (num > 100):
  print ("the number is out of range. The range is between 1 and 100 (inclusive). Try again")
  num = int (input ("Enter the size of this list: "))
even_numbers = [i for i in range(2, num + 1, 2)]  # Even numbers between 1 and num + 1
odd_numbers = [i for i in range(1, num + 1, 2)]   # Odd numbers between 1 and num + 1

try:
    code_passed = True
    if condition_test(num)[0] == even_numbers and condition_test(num)[1] == odd_numbers:
        pass
    else:
        code_passed = False
        print ('Code Incorrect, Expected result: {}'.format((even_numbers, odd_numbers)))

    if code_passed:
        print ("Code Correct")
        print("The two lists are: \n {} \n {}".format(condition_test(num)[0],condition_test(num)[1]))
except TypeError:
    print ('condition_test() method returns wrong value')
# Out:
# Enter the size of this list: 10
# Code Correct
# The two lists are:
#  [2, 4, 6, 8, 10]
#  [1, 3, 5, 7, 9]

# %% [markdown]
# #### Step 3 -- Write and run your own test (Optional)

# %% [markdown]
# Add your prompts used for generating this test code here:

# %%
# Add your test code here and compare with the provided one

# %% [markdown]
# #### Step 4 -- Design a scenario to use this function condition_test()

# %% [markdown]
# Add your prompts used for generating this function call here.

# %%
# Add your investigated code here

# %% [markdown]
# # Task 4

# %% [markdown]
# #### Step 1: Generate solution

# %% [markdown]
# Extract Task 4 specification and add it here for your reference:

# %% [markdown]
# Add your prompts for generating Task 4 solution here (starting and ending prompts attemped):

# %%
# Add your investigated solution of Task 4 here

# %% [markdown]
# #### Step 2 -- Create a test scenario:
# You are in a fruit shop. FruitPrices={'apples': 2.00, 'oranges': 1.50, 'pears': 1.75, 'limes': 0.75, 'strawberries': 1.00}
#
#
# You made two orders:
#
#
# orderList1 = [
#     ("apple", 2),
#     ("pears", 3),
#     ("limes", 4)
# ]
#
#
# orderList2 = [
#     ("apple", 4),
#     ("strawberry", 2),
#     ("orange", 3)
# ]

# %% [markdown]
# Add your prompts used for generating this test scenario here (an example prompt is given below. Use it as a reference to generate your own).

# %% [markdown]
# Suggested prompt: Write a python program in which a user can choose a fruit order from 2 predefined fruit orders in a fruit shop. If a user enters a number that is greater than 2, print a message "Wrong order code, try again within (1,2)". Save the chosen order in a dissctionary orderList. Use a dictionary to map fruits to their prices: apples to 2.00, oranges to 1.50, pears  to 1.75, limes to0.75 and strawberries to 1.00.
# In this task, two orders in one fruit shop are given as follows:
#  orderList1 = [('apples', 2.0), ('pears', 3.0), ('limes', 4.0)]
#  orderList2 = [ ('apples', 4.0), ('oranges',3.0), ('strawberries',2.0) ]
#
#  Don't calculate the total cost of an order. Display the fruit, quantity and price in the chosen order with necessary information. Don't include any examples.

# %%
# Add your investigated code here

# %%
#@title #### Step 3 -- Task 4 Test: Run this cell to test your solution.
"""Test """
solution_cost=0
for fruit, qty in orderList:
  solution_cost += fruitPrices[fruit]*qty

code_passed = True
if calculate_total_cost(orderList, fruitPrices) == solution_cost:
    pass
else:
    code_passed = False
    print ('Code Incorrect, Expect result: {}'.format(solution_cost))

if code_passed:
    print ("Code Correct")
# Out:
# Code Correct

# %% [markdown]
# #### Step 4 -- Write and run your own test (Optional)

# %% [markdown]
# Add your prompts used for generating this test code here:

# %%
# Add your test code here and compare with the provided one
